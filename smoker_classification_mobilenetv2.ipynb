# %% [markdown]
# <h1 style="font-family:verdana;"> <center> Smoker Classification using Deep Convolutional Neural Networks and Transfer Learning</center> </h1>

# %%
# Import Data Science Libraries
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
import itertools
import random

# Import visualization libraries
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import cv2

# Tensorflow Libraries
from tensorflow import keras
from tensorflow.keras import layers,models
from keras_preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import Callback, EarlyStopping,ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import Model
from tensorflow.keras.layers.experimental import preprocessing

# System libraries
from pathlib import Path
import os.path

# Metrics
from sklearn.metrics import classification_report, confusion_matrix
from helper_functions import create_tensorboard_callback, plot_loss_curves, unzip_data, compare_historys, walk_through_dir, pred_and_plot

# %% [markdown]
# # Load and Transform Data

# %%
BATCH_SIZE = 32
IMAGE_SIZE = (300, 300)

# %%
# Walk through each directory
dataset = "../input/cigarette-smoker-detection/"
walk_through_dir(dataset)
# Out:
# There are 1 directories and 0 images in '../input/cigarette-smoker-detection/'.
# There are 3 directories and 1 images in '../input/cigarette-smoker-detection/data'.
# There are 0 directories and 1279 images in '../input/cigarette-smoker-detection/data/not_smoking'.
# There are 0 directories and 1996 images in '../input/cigarette-smoker-detection/data/smoking'.
# There are 2 directories and 1 images in '../input/cigarette-smoker-detection/data/data'.
# There are 0 directories and 1279 images in '../input/cigarette-smoker-detection/data/data/not_smoking'.
# There are 0 directories and 1996 images in '../input/cigarette-smoker-detection/data/data/smoking'.

# %% [markdown]
# # Placing data into a Dataframe

# %%
image_dir = Path(dataset)

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.JPG')) + list(image_dir.glob(r'**/*.jpg')) + list(image_dir.glob(r'**/*.png'))  + list(image_dir.glob(r'**/*.jpeg')) + list(image_dir.glob(r'**/*.gif'))

labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# %%
image_df
# Out:
#                                                Filepath        Label
# 0     ../input/cigarette-smoker-detection/data/not_s...  not_smoking
# 1     ../input/cigarette-smoker-detection/data/not_s...  not_smoking
# 2     ../input/cigarette-smoker-detection/data/not_s...  not_smoking
# 3     ../input/cigarette-smoker-detection/data/not_s...  not_smoking
# 4     ../input/cigarette-smoker-detection/data/not_s...  not_smoking
# ...                                                 ...          ...
# 6531  ../input/cigarette-smoker-detection/data/data/...      smoking
# 6532  ../input/cigarette-smoker-detection/data/data/...      smoking
# 6533  ../input/cigarette-smoker-detection/data/data/...      smoking
# 6534  ../input/cigarette-smoker-detection/data/data/...      smoking
# 6535  ../input/cigarette-smoker-detection/data/data/...      smoking
#
# [6536 rows x 2 columns]

# %% [markdown]
# # Data Preprocessing
# <p style="font-size:15px; font-family:verdana; line-height: 1.7em">The data will be split into three different categories: Training, Validation and Testing. The training data will be used to train the deep learning CNN model and its parameters will be fine tuned with the validation data. Finally, the performance of the data will be evaluated using the test data(data the model has not previously seen).</p>

# %%
# Separate in train and test data
train_df, test_df = train_test_split(image_df, test_size=0.2, shuffle=True, random_state=42)

# %%
train_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,
    validation_split=0.2
)

test_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
)

# %%
# Split the data into three categories.
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='validation'
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# /opt/conda/lib/python3.7/site-packages/keras_preprocessing/image/dataframe_iterator.py:282: UserWarning: Found 29 invalid image filename(s) in x_col="Filepath". These filename(s) will be ignored.
#   .format(n_invalid, x_col)
# Found 4160 validated image filenames belonging to 2 classes.
# Found 1039 validated image filenames belonging to 2 classes.
# Found 1297 validated image filenames belonging to 2 classes.
# /opt/conda/lib/python3.7/site-packages/keras_preprocessing/image/dataframe_iterator.py:282: UserWarning: Found 11 invalid image filename(s) in x_col="Filepath". These filename(s) will be ignored.
#   .format(n_invalid, x_col)

# %%
# Resize Layer
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(224,224),
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.experimental.preprocessing.RandomFlip("horizontal"),
  layers.experimental.preprocessing.RandomRotation(0.1),
  layers.experimental.preprocessing.RandomZoom(0.1),
  layers.experimental.preprocessing.RandomContrast(0.1),
])

# %% [markdown]
# # 🤹Training the model
# <p style="font-size:15px; font-family:verdana; line-height: 1.7em">The model images will be subjected to a pre-trained CNN model called MobileNetV2. Three callbacks will be utilized to monitor the training. These are: Model Checkpoint, Early Stopping, Tensorboard callback. The summary of the model hyperparameter is shown as follows:</p>
#
# **Batch size** : 32
#
# **Epochs** : 100
#
# **Input Shape** : (224, 224, 3)
#
# **Output layer** : 2

# %%
# Load the pretained model
pretrained_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='max'
)

pretrained_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step

# %%
# Create checkpoint callback
checkpoint_path = "smokers_classification_model_checkpoint"
checkpoint_callback = ModelCheckpoint(checkpoint_path,
                                      save_weights_only=True,
                                      monitor="val_accuracy",
                                      save_best_only=True)

# %%
# Setup EarlyStopping callback to stop training if model's val_loss doesn't improve for 5 epochs
early_stopping = EarlyStopping(monitor = "val_loss", # watch the val loss metric
                               patience = 5,
                               restore_best_weights = True) # if val loss decreases for 5 epochs in a row, stop training

# %% [markdown]
# # 🚄Training the model

# %%
inputs = pretrained_model.input
x = resize_and_rescale(inputs)

x = Dense(256, activation='relu')(pretrained_model.output)
x = Dropout(0.45)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.45)(x)


outputs = Dense(2, activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer=Adam(0.00001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    steps_per_epoch=len(train_images),
    validation_data=val_images,
    validation_steps=len(val_images),
    epochs=100,
    callbacks=[
        early_stopping,
        create_tensorboard_callback("training_logs", 
                                    "smoker_classification"),
        checkpoint_callback,
    ]
)
# Out:
# Saving TensorBoard log files to: training_logs/smoker_classification/20230225-113646
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 1/100
#  13/130 [==>...........................] - ETA: 1:46 - loss: 3.4113 - accuracy: 0.4639
# /opt/conda/lib/python3.7/site-packages/PIL/Image.py:993: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 130/130 [==============================] - 192s 1s/step - loss: 2.8237 - accuracy: 0.5320 - val_loss: 1.4252 - val_accuracy: 0.6112
# Epoch 2/100
# 130/130 [==============================] - 145s 1s/step - loss: 2.1881 - accuracy: 0.5582 - val_loss: 1.0703 - val_accuracy: 0.6487
# Epoch 3/100
# 130/130 [==============================] - 144s 1s/step - loss: 1.7009 - accuracy: 0.5882 - val_loss: 0.8129 - val_accuracy: 0.6862
# Epoch 4/100
# 130/130 [==============================] - 143s 1s/step - loss: 1.4039 - accuracy: 0.6132 - val_loss: 0.7461 - val_accuracy: 0.6949
# Epoch 5/100
# 130/130 [==============================] - 145s 1s/step - loss: 1.2265 - accuracy: 0.6264 - val_loss: 0.6928 - val_accuracy: 0.7103
# Epoch 6/100
# 130/130 [==============================] - 144s 1s/step - loss: 1.0829 - accuracy: 0.6300 - val_loss: 0.6415 - val_accuracy: 0.7315
# Epoch 7/100
# 130/130 [==============================] - 143s 1s/step - loss: 0.9721 - accuracy: 0.6548 - val_loss: 0.6147 - val_accuracy: 0.7372
# Epoch 8/100
# 130/130 [==============================] - 143s 1s/step - loss: 0.9485 - accuracy: 0.6582 - val_loss: 0.5759 - val_accuracy: 0.7449
# Epoch 9/100
# 130/130 [==============================] - 146s 1s/step - loss: 0.8869 - accuracy: 0.6685 - val_loss: 0.5507 - val_accuracy: 0.7421
# Epoch 10/100
# 130/130 [==============================] - 145s 1s/step - loss: 0.8099 - accuracy: 0.6724 - val_loss: 0.5291 - val_accuracy: 0.7469
# Epoch 11/100
# 130/130 [==============================] - 154s 1s/step - loss: 0.7690 - accuracy: 0.6865 - val_loss: 0.5216 - val_accuracy: 0.7498
# Epoch 12/100
# 130/130 [==============================] - 147s 1s/step - loss: 0.7536 - accuracy: 0.6861 - val_loss: 0.5253 - val_accuracy: 0.7575
# Epoch 13/100
# 130/130 [==============================] - 145s 1s/step - loss: 0.7311 - accuracy: 0.6837 - val_loss: 0.5018 - val_accuracy: 0.7594
# Epoch 14/100
# 130/130 [==============================] - 143s 1s/step - loss: 0.6976 - accuracy: 0.6959 - val_loss: 0.4949 - val_accuracy: 0.7671
# Epoch 15/100
# 130/130 [==============================] - 145s 1s/step - loss: 0.6517 - accuracy: 0.7082 - val_loss: 0.4937 - val_accuracy: 0.7680
# Epoch 16/100
# 130/130 [==============================] - 143s 1s/step - loss: 0.6437 - accuracy: 0.7154 - val_loss: 0.4818 - val_accuracy: 0.7757
# Epoch 17/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.6193 - accuracy: 0.7236 - val_loss: 0.4819 - val_accuracy: 0.7806
# Epoch 18/100
# 130/130 [==============================] - 143s 1s/step - loss: 0.5908 - accuracy: 0.7320 - val_loss: 0.4675 - val_accuracy: 0.7844
# Epoch 19/100
# 130/130 [==============================] - 173s 1s/step - loss: 0.5909 - accuracy: 0.7240 - val_loss: 0.4677 - val_accuracy: 0.7825
# Epoch 20/100
# 130/130 [==============================] - 163s 1s/step - loss: 0.5641 - accuracy: 0.7411 - val_loss: 0.4652 - val_accuracy: 0.7844
# Epoch 21/100
# 130/130 [==============================] - 142s 1s/step - loss: 0.5473 - accuracy: 0.7474 - val_loss: 0.4575 - val_accuracy: 0.7844
# Epoch 22/100
# 130/130 [==============================] - 143s 1s/step - loss: 0.5385 - accuracy: 0.7462 - val_loss: 0.4450 - val_accuracy: 0.7911
# Epoch 23/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.5490 - accuracy: 0.7464 - val_loss: 0.4421 - val_accuracy: 0.7940
# Epoch 24/100
# 130/130 [==============================] - 145s 1s/step - loss: 0.5231 - accuracy: 0.7572 - val_loss: 0.4429 - val_accuracy: 0.7931
# Epoch 25/100
# 130/130 [==============================] - 157s 1s/step - loss: 0.5251 - accuracy: 0.7531 - val_loss: 0.4358 - val_accuracy: 0.8017
# Epoch 26/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.5284 - accuracy: 0.7538 - val_loss: 0.4328 - val_accuracy: 0.7988
# Epoch 27/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.5136 - accuracy: 0.7611 - val_loss: 0.4279 - val_accuracy: 0.8056
# Epoch 28/100
# 130/130 [==============================] - 145s 1s/step - loss: 0.4770 - accuracy: 0.7798 - val_loss: 0.4275 - val_accuracy: 0.8037
# Epoch 29/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.5036 - accuracy: 0.7683 - val_loss: 0.4173 - val_accuracy: 0.8027
# Epoch 30/100
# 130/130 [==============================] - 143s 1s/step - loss: 0.4852 - accuracy: 0.7784 - val_loss: 0.4196 - val_accuracy: 0.8027
# Epoch 31/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.4687 - accuracy: 0.7839 - val_loss: 0.4118 - val_accuracy: 0.8046
# Epoch 32/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.4759 - accuracy: 0.7815 - val_loss: 0.4085 - val_accuracy: 0.8037
# Epoch 33/100
# 130/130 [==============================] - 148s 1s/step - loss: 0.4649 - accuracy: 0.7897 - val_loss: 0.4086 - val_accuracy: 0.8104
# Epoch 34/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.4512 - accuracy: 0.7923 - val_loss: 0.4040 - val_accuracy: 0.8085
# Epoch 35/100
# 130/130 [==============================] - 145s 1s/step - loss: 0.4454 - accuracy: 0.7928 - val_loss: 0.4028 - val_accuracy: 0.8123
# Epoch 36/100
# 130/130 [==============================] - 146s 1s/step - loss: 0.4383 - accuracy: 0.7971 - val_loss: 0.3961 - val_accuracy: 0.8171
# Epoch 37/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.4377 - accuracy: 0.7993 - val_loss: 0.3949 - val_accuracy: 0.8152
# Epoch 38/100
# 130/130 [==============================] - 146s 1s/step - loss: 0.4392 - accuracy: 0.8012 - val_loss: 0.3866 - val_accuracy: 0.8248
# Epoch 39/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.4285 - accuracy: 0.8055 - val_loss: 0.3895 - val_accuracy: 0.8229
# Epoch 40/100
# 130/130 [==============================] - 146s 1s/step - loss: 0.4378 - accuracy: 0.8053 - val_loss: 0.3831 - val_accuracy: 0.8210
# Epoch 41/100
# 130/130 [==============================] - 147s 1s/step - loss: 0.4270 - accuracy: 0.8067 - val_loss: 0.3819 - val_accuracy: 0.8239
# Epoch 42/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.4173 - accuracy: 0.8151 - val_loss: 0.3771 - val_accuracy: 0.8345
# Epoch 43/100
# 130/130 [==============================] - 146s 1s/step - loss: 0.4105 - accuracy: 0.8173 - val_loss: 0.3783 - val_accuracy: 0.8306
# Epoch 44/100
# 130/130 [==============================] - 145s 1s/step - loss: 0.4023 - accuracy: 0.8240 - val_loss: 0.3785 - val_accuracy: 0.8335
# Epoch 45/100
# 130/130 [==============================] - 145s 1s/step - loss: 0.3954 - accuracy: 0.8286 - val_loss: 0.3733 - val_accuracy: 0.8325
# Epoch 46/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.3935 - accuracy: 0.8264 - val_loss: 0.3714 - val_accuracy: 0.8335
# Epoch 47/100
# 130/130 [==============================] - 162s 1s/step - loss: 0.3861 - accuracy: 0.8310 - val_loss: 0.3685 - val_accuracy: 0.8335
# Epoch 48/100
# 130/130 [==============================] - 156s 1s/step - loss: 0.3819 - accuracy: 0.8325 - val_loss: 0.3710 - val_accuracy: 0.8354
# Epoch 49/100
# 130/130 [==============================] - 153s 1s/step - loss: 0.3799 - accuracy: 0.8363 - val_loss: 0.3634 - val_accuracy: 0.8393
# Epoch 50/100
# 130/130 [==============================] - 152s 1s/step - loss: 0.3719 - accuracy: 0.8399 - val_loss: 0.3584 - val_accuracy: 0.8489
# Epoch 51/100
# 130/130 [==============================] - 146s 1s/step - loss: 0.3757 - accuracy: 0.8421 - val_loss: 0.3593 - val_accuracy: 0.8470
# Epoch 52/100
# 130/130 [==============================] - 145s 1s/step - loss: 0.3734 - accuracy: 0.8397 - val_loss: 0.3586 - val_accuracy: 0.8422
# Epoch 53/100
# 130/130 [==============================] - 145s 1s/step - loss: 0.3613 - accuracy: 0.8406 - val_loss: 0.3513 - val_accuracy: 0.8489
# Epoch 54/100
# 130/130 [==============================] - 145s 1s/step - loss: 0.3531 - accuracy: 0.8471 - val_loss: 0.3518 - val_accuracy: 0.8460
# Epoch 55/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.3406 - accuracy: 0.8519 - val_loss: 0.3503 - val_accuracy: 0.8489
# Epoch 56/100
# 130/130 [==============================] - 147s 1s/step - loss: 0.3484 - accuracy: 0.8486 - val_loss: 0.3470 - val_accuracy: 0.8527
# Epoch 57/100
# 130/130 [==============================] - 157s 1s/step - loss: 0.3395 - accuracy: 0.8613 - val_loss: 0.3376 - val_accuracy: 0.8595
# Epoch 58/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.3348 - accuracy: 0.8606 - val_loss: 0.3375 - val_accuracy: 0.8614
# Epoch 59/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.3301 - accuracy: 0.8543 - val_loss: 0.3345 - val_accuracy: 0.8624
# Epoch 60/100
# 130/130 [==============================] - 145s 1s/step - loss: 0.3301 - accuracy: 0.8613 - val_loss: 0.3398 - val_accuracy: 0.8566
# Epoch 61/100
# 130/130 [==============================] - 149s 1s/step - loss: 0.3386 - accuracy: 0.8555 - val_loss: 0.3332 - val_accuracy: 0.8633
# Epoch 62/100
# 130/130 [==============================] - 149s 1s/step - loss: 0.3225 - accuracy: 0.8620 - val_loss: 0.3370 - val_accuracy: 0.8527
# Epoch 63/100
# 130/130 [==============================] - 145s 1s/step - loss: 0.3047 - accuracy: 0.8719 - val_loss: 0.3282 - val_accuracy: 0.8643
# Epoch 64/100
# 130/130 [==============================] - 146s 1s/step - loss: 0.3102 - accuracy: 0.8690 - val_loss: 0.3244 - val_accuracy: 0.8691
# Epoch 65/100
# 130/130 [==============================] - 145s 1s/step - loss: 0.3113 - accuracy: 0.8719 - val_loss: 0.3252 - val_accuracy: 0.8653
# Epoch 66/100
# 130/130 [==============================] - 150s 1s/step - loss: 0.3015 - accuracy: 0.8724 - val_loss: 0.3221 - val_accuracy: 0.8672
# Epoch 67/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.3029 - accuracy: 0.8700 - val_loss: 0.3191 - val_accuracy: 0.8701
# Epoch 68/100
# 130/130 [==============================] - 147s 1s/step - loss: 0.3067 - accuracy: 0.8683 - val_loss: 0.3221 - val_accuracy: 0.8653
# Epoch 69/100
# 130/130 [==============================] - 149s 1s/step - loss: 0.2935 - accuracy: 0.8762 - val_loss: 0.3227 - val_accuracy: 0.8730
# Epoch 70/100
# 130/130 [==============================] - 158s 1s/step - loss: 0.2940 - accuracy: 0.8779 - val_loss: 0.3161 - val_accuracy: 0.8730
# Epoch 71/100
# 130/130 [==============================] - 145s 1s/step - loss: 0.2856 - accuracy: 0.8844 - val_loss: 0.3171 - val_accuracy: 0.8730
# Epoch 72/100
# 130/130 [==============================] - 143s 1s/step - loss: 0.2795 - accuracy: 0.8873 - val_loss: 0.3075 - val_accuracy: 0.8758
# Epoch 73/100
# 130/130 [==============================] - 143s 1s/step - loss: 0.2734 - accuracy: 0.8868 - val_loss: 0.3060 - val_accuracy: 0.8807
# Epoch 74/100
# 130/130 [==============================] - 142s 1s/step - loss: 0.2767 - accuracy: 0.8885 - val_loss: 0.3108 - val_accuracy: 0.8758
# Epoch 75/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.2782 - accuracy: 0.8887 - val_loss: 0.3058 - val_accuracy: 0.8816
# Epoch 76/100
# 130/130 [==============================] - 145s 1s/step - loss: 0.2676 - accuracy: 0.8918 - val_loss: 0.3081 - val_accuracy: 0.8807
# Epoch 77/100
# 130/130 [==============================] - 158s 1s/step - loss: 0.2620 - accuracy: 0.8957 - val_loss: 0.3034 - val_accuracy: 0.8807
# Epoch 78/100
# 130/130 [==============================] - 149s 1s/step - loss: 0.2622 - accuracy: 0.8928 - val_loss: 0.3047 - val_accuracy: 0.8835
# Epoch 79/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.2557 - accuracy: 0.8988 - val_loss: 0.2958 - val_accuracy: 0.8797
# Epoch 80/100
# 130/130 [==============================] - 143s 1s/step - loss: 0.2562 - accuracy: 0.8964 - val_loss: 0.2940 - val_accuracy: 0.8835
# Epoch 81/100
# 130/130 [==============================] - 149s 1s/step - loss: 0.2557 - accuracy: 0.8959 - val_loss: 0.2947 - val_accuracy: 0.8816
# Epoch 82/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.2552 - accuracy: 0.8945 - val_loss: 0.2932 - val_accuracy: 0.8845
# Epoch 83/100
# 130/130 [==============================] - 143s 1s/step - loss: 0.2524 - accuracy: 0.8978 - val_loss: 0.2889 - val_accuracy: 0.8855
# Epoch 84/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.2400 - accuracy: 0.9055 - val_loss: 0.2855 - val_accuracy: 0.8816
# Epoch 85/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.2348 - accuracy: 0.9089 - val_loss: 0.2816 - val_accuracy: 0.8864
# Epoch 86/100
# 130/130 [==============================] - 146s 1s/step - loss: 0.2379 - accuracy: 0.9034 - val_loss: 0.2795 - val_accuracy: 0.8864
# Epoch 87/100
# 130/130 [==============================] - 149s 1s/step - loss: 0.2204 - accuracy: 0.9166 - val_loss: 0.2954 - val_accuracy: 0.8845
# Epoch 88/100
# 130/130 [==============================] - 143s 1s/step - loss: 0.2234 - accuracy: 0.9127 - val_loss: 0.2827 - val_accuracy: 0.8855
# Epoch 89/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.2119 - accuracy: 0.9161 - val_loss: 0.2790 - val_accuracy: 0.8951
# Epoch 90/100
# 130/130 [==============================] - 143s 1s/step - loss: 0.2194 - accuracy: 0.9142 - val_loss: 0.2843 - val_accuracy: 0.8922
# Epoch 91/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.2158 - accuracy: 0.9168 - val_loss: 0.2808 - val_accuracy: 0.8893
# Epoch 92/100
# 130/130 [==============================] - 143s 1s/step - loss: 0.2131 - accuracy: 0.9168 - val_loss: 0.2759 - val_accuracy: 0.8893
# Epoch 93/100
# 130/130 [==============================] - 149s 1s/step - loss: 0.2054 - accuracy: 0.9144 - val_loss: 0.2745 - val_accuracy: 0.8912
# Epoch 94/100
# 130/130 [==============================] - 152s 1s/step - loss: 0.2041 - accuracy: 0.9228 - val_loss: 0.2781 - val_accuracy: 0.8941
# Epoch 95/100
# 130/130 [==============================] - 145s 1s/step - loss: 0.2032 - accuracy: 0.9233 - val_loss: 0.2728 - val_accuracy: 0.8989
# Epoch 96/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.1915 - accuracy: 0.9260 - val_loss: 0.2667 - val_accuracy: 0.8999
# Epoch 97/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.1943 - accuracy: 0.9269 - val_loss: 0.2697 - val_accuracy: 0.8961
# Epoch 98/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.1957 - accuracy: 0.9264 - val_loss: 0.2651 - val_accuracy: 0.8989
# Epoch 99/100
# 130/130 [==============================] - 146s 1s/step - loss: 0.1983 - accuracy: 0.9243 - val_loss: 0.2600 - val_accuracy: 0.8999
# Epoch 100/100
# 130/130 [==============================] - 144s 1s/step - loss: 0.1816 - accuracy: 0.9325 - val_loss: 0.2618 - val_accuracy: 0.8989

# %% [markdown]
# # ✔️Model Evaluation

# %%
results = model.evaluate(test_images, verbose=0)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
#     Test Loss: 0.23271
# Test Accuracy: 92.21%

# %% [markdown]
# # 📉Visualizing loss curves

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')

plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')

plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# # 🔮Making predictions on the Test Data

# %%
# Predict the label of the test_images
pred = model.predict(test_images)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# Display the result
print(f'The first 5 predictions: {pred[:5]}')
# Out:
# The first 5 predictions: ['smoking', 'smoking', 'not_smoking', 'not_smoking', 'smoking']

# %% [markdown]
# # Plotting the Classification Reports and Confusion Matrix

# %%
y_test = list(test_df.Label)
print(classification_report(y_test[:-11], pred))
# Out:
#               precision    recall  f1-score   support
#
#  not_smoking       0.48      0.43      0.45       521
#      smoking       0.64      0.69      0.66       776
#
#     accuracy                           0.58      1297
#    macro avg       0.56      0.56      0.56      1297
# weighted avg       0.58      0.58      0.58      1297

# %%
report = classification_report(y_test[:-11], pred, output_dict=True)
df = pd.DataFrame(report).transpose()
df
# Out:
#               precision    recall  f1-score      support
# not_smoking    0.478541  0.428023  0.451874   521.000000
# smoking        0.641396  0.686856  0.663348   776.000000
# accuracy       0.582884  0.582884  0.582884     0.582884
# macro avg      0.559968  0.557439  0.557611  1297.000000
# weighted avg   0.575978  0.582884  0.578400  1297.000000

# %%
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(15, 7), text_size=10, norm=False, savefig=False): 
    """Makes a labelled confusion matrix comparing predictions and ground truth labels.

    If classes is passed, confusion matrix will be labelled, if not, integer class values
  will be used.

  Args:
    y_true: Array of truth labels (must be same shape as y_pred).
    y_pred: Array of predicted labels (must be same shape as y_true).
    classes: Array of class labels (e.g. string form). If `None`, integer labels are used.
    figsize: Size of output figure (default=(10, 10)).
    text_size: Size of output figure text (default=15).
    norm: normalize values or not (default=False).
    savefig: save confusion matrix to file (default=False).
  
  Returns:
    A labelled confusion matrix plot comparing y_true and y_pred.

  Example usage:
    make_confusion_matrix(y_true=test_labels, # ground truth test labels
                          y_pred=y_preds, # predicted labels
                          classes=class_names, # array of class label names
                          figsize=(15, 15),
                          text_size=10)
    """  
  # Create the confustion matrix
    cm = confusion_matrix(y_true, y_pred)
    cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
    n_classes = cm.shape[0] # find the number of classes we're dealing with

    # Plot the figure and make it pretty
    fig, ax = plt.subplots(figsize=figsize)
    cax = ax.matshow(cm, cmap=plt.cm.Blues) # colors will represent how 'correct' a class is, darker == better
    fig.colorbar(cax)

    # Are there a list of classes?
    if classes:
        labels = classes
    else:
        labels = np.arange(cm.shape[0])
  
    # Label the axes
    ax.set(title="Confusion Matrix",
         xlabel="Predicted label",
         ylabel="True label",
         xticks=np.arange(n_classes), # create enough axis slots for each class
         yticks=np.arange(n_classes), 
         xticklabels=labels, # axes will labeled with class names (if they exist) or ints
         yticklabels=labels)
  
    # Make x-axis labels appear on bottom
    ax.xaxis.set_label_position("bottom")
    ax.xaxis.tick_bottom()
    ### Added: Rotate xticks for readability & increase font size (required due to such a large confusion matrix)
    plt.xticks(rotation=90, fontsize=text_size)
    plt.yticks(fontsize=text_size)

    # Set the threshold for different colors
    threshold = (cm.max() + cm.min()) / 2.

    # Plot the text on each cell
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if norm:
            plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
                horizontalalignment="center",
                color="white" if cm[i, j] > threshold else "black",
                size=text_size)
        else:
            plt.text(j, i, f"{cm[i, j]}",
              horizontalalignment="center",
              color="white" if cm[i, j] > threshold else "black",
              size=text_size)

  # Save the figure to the current working directory
    if savefig:
        fig.savefig("confusion_matrix.png")

# %%
make_confusion_matrix(y_test[:-11], pred, list(labels.values()))
